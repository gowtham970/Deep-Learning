# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham970/Deep-Learning/blob/main/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Flatten the input images
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# Normalize the input images
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# One-hot encode the target labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Define the model
model = Sequential()
model.add(Dense(128, input_shape=(784,), activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(X_test, y_test))

# Plot the training and test loss curves
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curves')
plt.legend()
plt.show()


plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Training and Test Loss Curves')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 469/469 [==============================] - 3s 4ms/step - loss: 0.3339 - accuracy: 0.9042 - val_loss: 0.1569 - val_accuracy: 0.9535
# Epoch 2/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1374 - accuracy: 0.9598 - val_loss: 0.1203 - val_accuracy: 0.9641
# Epoch 3/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0947 - accuracy: 0.9710 - val_loss: 0.0961 - val_accuracy: 0.9705
# Epoch 4/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0725 - accuracy: 0.9778 - val_loss: 0.0891 - val_accuracy: 0.9722
# Epoch 5/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0565 - accuracy: 0.9823 - val_loss: 0.0775 - val_accuracy: 0.9750
# Epoch 6/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0456 - accuracy: 0.9862 - val_loss: 0.0791 - val_accuracy: 0.9742
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0359 - accuracy: 0.9889 - val_loss: 0.0837 - val_accuracy: 0.9739
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.0773 - val_accuracy: 0.9759
# Epoch 9/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0247 - accuracy: 0.9925 - val_loss: 0.0810 - val_accuracy: 0.9759
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 0.0722 - val_accuracy: 0.9772
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.0789 - val_accuracy: 0.9766
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0798 - val_accuracy: 0.9778
# Epoch 13/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.0863 - val_accuracy: 0.9778
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0939 - val_accuracy: 0.9759
# Epoch 15/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.0861 - val_accuracy: 0.9783
# Epoch 16/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0941 - val_accuracy: 0.9774
# Epoch 17/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0968 - val_accuracy: 0.9776
# Epoch 18/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0945 - val_accuracy: 0.9787
# Epoch 19/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.1020 - val_accuracy: 0.9773
# Epoch 20/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.1079 - val_accuracy: 0.9760
